# %%
import pandas as pd
from clean_region_names import replacing

# %%
df_Subject_Scores = pd.read_csv("Fənlər_üzrə_nisbi_balların_dinamikası.csv")

# %%
df_Subject_Scores.head()
# Out:
#      İl                   Bölgə                Məktəb      Fənn      Cins  \
# 0  2012  Bakı Ş. Yasamal Rayonu  13 saylı orta məktəb  Ana dili  oğlanlar
# 1  2013  Bakı Ş. Yasamal Rayonu  13 saylı orta məktəb  Ana dili  oğlanlar
# 2  2014  Bakı Ş. Yasamal Rayonu  13 saylı orta məktəb  Ana dili  oğlanlar
# 3  2015  Bakı Ş. Yasamal Rayonu  13 saylı orta məktəb  Ana dili  oğlanlar
# 4  2016  Bakı Ş. Yasamal Rayonu  13 saylı orta məktəb  Ana dili  oğlanlar
#
#    Düzgün cavabların faizi  Reytinq      Buraxılış_imtahanları
# 0                    47.62    0.996  tam orta təhsil səviyyəsi
# 1                    47.28    1.015  tam orta təhsil səviyyəsi
# 2                    55.65    1.109  tam orta təhsil səviyyəsi
# 3                    43.64    0.923  tam orta təhsil səviyyəsi
# 4                    58.43    1.171  tam orta təhsil səviyyəsi

# %%
df_Subject_Scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041177 entries, 0 to 1041176
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   İl                       1041177 non-null  int64
#  1   Bölgə                    1041177 non-null  object
#  2   Məktəb                   1041177 non-null  object
#  3   Fənn                     1038618 non-null  object
#  4   Cins                     1041177 non-null  object
#  5   Düzgün cavabların faizi  778060 non-null   float64
#  6   Reytinq                  778060 non-null   float64
#  7   Buraxılış_imtahanları    1041177 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 63.5+ MB

# %%
replacing(df_Subject_Scores, "Bölgə")
# Out:
#            İl                       Bölgə                      Məktəb  \
# 0        2012  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 1        2013  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 2        2014  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 3        2015  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 4        2016  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# ...       ...                         ...                         ...
# 1041172  2020              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1041173  2021              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1041174  2022              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1041175  2023              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1041176  2024              siyəzən rayonu  6 saylı şəhər orta məktəbi
#
#                                   Fənn        Cins  Düzgün cavabların faizi  \
# ...

# %%
df_Subject_Scores.isnull().sum()
# Out:
# İl                              0
# Bölgə                           0
# Məktəb                          0
# Fənn                         2559
# Cins                            0
# Düzgün cavabların faizi    263117
# Reytinq                    263117
# Buraxılış_imtahanları           0
# dtype: int64

# %%
df_Subject_Scores[df_Subject_Scores['Fənn'].isna()]
# Out:
#            İl                       Bölgə                       Məktəb Fənn  \
# 5265     2012  bakı şəhəri yasamal rayonu        172 saylı orta məktəb  NaN
# 5266     2013  bakı şəhəri yasamal rayonu        172 saylı orta məktəb  NaN
# 5267     2014  bakı şəhəri yasamal rayonu        172 saylı orta məktəb  NaN
# 5268     2015  bakı şəhəri yasamal rayonu        172 saylı orta məktəb  NaN
# 5269     2016  bakı şəhəri yasamal rayonu        172 saylı orta məktəb  NaN
# ...       ...                         ...                          ...  ...
# 1019917  2020               xaçmaz rayonu  Suxtakələ kənd orta məktəbi  NaN
# 1019918  2021               xaçmaz rayonu  Suxtakələ kənd orta məktəbi  NaN
# 1019919  2022               xaçmaz rayonu  Suxtakələ kənd orta məktəbi  NaN
# 1019920  2023               xaçmaz rayonu  Suxtakələ kənd orta məktəbi  NaN
# 1019921  2024               xaçmaz rayonu  Suxtakələ kənd orta məktəbi  NaN
#
#                Cins  Düzgün cavabların faizi  Reytinq  \
# ...

# %%
# Məlumat mənbəsində bu müşahidələr üzrə performans göstəriciləri mövcud deyil.
# Subyektiv və ya fərziyyəyə əsaslanan doldurma analitik nəticələrin düzgünlüyünə
# mənfi təsir göstərə biləcəyi üçün bu sətrləri silirəm.
df_Subject_Scores.dropna(subset=('Fənn', 'Düzgün cavabların faizi', 'Reytinq'), inplace=True)

# %%
df_Subject_Scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777361 entries, 0 to 1041176
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   İl                       777361 non-null  int64
#  1   Bölgə                    777361 non-null  object
#  2   Məktəb                   777361 non-null  object
#  3   Fənn                     777361 non-null  object
#  4   Cins                     777361 non-null  object
#  5   Düzgün cavabların faizi  777361 non-null  float64
#  6   Reytinq                  777361 non-null  float64
#  7   Buraxılış_imtahanları    777361 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 53.4+ MB

# %%
df_Subject_Scores.to_csv("Fənlər_üzrə_nisbi_balların_dinamikası_cleaned.csv", index=False, encoding="utf-8-sig")
