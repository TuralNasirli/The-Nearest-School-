# %%
import pandas as pd
from clean_region_names import replacing

# %%
df_exam_score = pd.read_csv("İmtahan_fənləri_üzrə_cavabların_göstəricilər.csv")

# %%
df_exam_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301792 entries, 0 to 1301791
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   İl                                1301792 non-null  int64
#  1   Bölgə                             1301792 non-null  object
#  2   Məktəb                            1301792 non-null  object
#  3   Fənn                              1301792 non-null  object
#  4   Cins                              1301792 non-null  object
#  5   İmtahanda iştirak edənlərin sayı  1301792 non-null  int64
#  6   Düzgün cavabların faizi           1134160 non-null  float64
#  7   Reytinq                           1134160 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 79.5+ MB

# %%
replacing(df_exam_score, "Bölgə")
# Out:
#            İl                       Bölgə                      Məktəb  \
# 0        1995  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 1        1995  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 2        1995  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 3        1995  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 4        1995  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# ...       ...                         ...                         ...
# 1301787  2024              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1301788  2024              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1301789  2024              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1301790  2024              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1301791  2024              siyəzən rayonu  6 saylı şəhər orta məktəbi
#
#                 Fənn   Cins  İmtahanda iştirak edənlərin sayı  \
# 0           Ana dili  Oğlan                                20
# ...

# %%
df_exam_score.head()
# Out:
#      İl                       Bölgə                Məktəb        Fənn   Cins  \
# 0  1995  bakı şəhəri yasamal rayonu  13 saylı orta məktəb    Ana dili  Oğlan
# 1  1995  bakı şəhəri yasamal rayonu  13 saylı orta məktəb    Ana dili    Qız
# 2  1995  bakı şəhəri yasamal rayonu  13 saylı orta məktəb   Ədəbiyyat  Oğlan
# 3  1995  bakı şəhəri yasamal rayonu  13 saylı orta məktəb   Ədəbiyyat    Qız
# 4  1995  bakı şəhəri yasamal rayonu  13 saylı orta məktəb  Riyaziyyat  Oğlan
#
#    İmtahanda iştirak edənlərin sayı  Düzgün cavabların faizi  Reytinq
# 0                                20                    30.33  0.87641
# 1                                26                    29.03  0.83879
# 2                                20                    37.44  1.02743
# 3                                26                    41.50  1.13902
# 4                                 8                    37.82  1.02103

# %%
df_exam_score[df_exam_score["Düzgün cavabların faizi"].isna()] # Burda imtahanda iştirak edənləri sayı sıfır olduğu üçün NaN düşüb.
# Out:
#            İl                       Bölgə                      Məktəb  \
# 38       1996  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 61       1997  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 101      1999  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 122      2000  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# 142      2001  bakı şəhəri yasamal rayonu        13 saylı orta məktəb
# ...       ...                         ...                         ...
# 1301747  2021              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1301754  2022              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1301756  2022              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1301758  2022              siyəzən rayonu  6 saylı şəhər orta məktəbi
# 1301791  2024              siyəzən rayonu  6 saylı şəhər orta məktəbi
#
#                 Fənn   Cins  İmtahanda iştirak edənlərin sayı  \
# 38         Türk dili  Oğlan                                 0
# ...

# %%
cols = ["Düzgün cavabların faizi", "Reytinq"]

df_exam_score.loc[
    df_exam_score["İmtahanda iştirak edənlərin sayı"] == 0,
    cols] = 0

# %%
df_exam_score[df_exam_score["Düzgün cavabların faizi"].isna()]
# Out:
# Empty DataFrame
# Columns: [İl, Bölgə, Məktəb, Fənn, Cins, İmtahanda iştirak edənlərin sayı, Düzgün cavabların faizi, Reytinq]
# Index: []

# %%
df_exam_score.to_csv("İmtahan_fənləri_üzrə_cavabların_göstəricilər_cleaned.csv", index=False, encoding="utf-8-sig")
